# %%
from selenium import webdriver
import bs4
import pandas as pd

# %%
driver = webdriver.Chrome('C:/Users/My PC/Downloads/chromedriver')
driver.get("https://www.theceomagazine.com/executive-interviews")

# %%
uid = driver.find_elements_by_class_name("widget-body")

for a in uid:
    print(a.text)
    link = a.find_elements_by_tag_name("a")
#     for x in link:
    print(link[1].get_attribute("href"))
    print("-"*70)
# Out:
# EXECUTIVE-INTERVIEWS
# Failures make us stronger: Wilfredo Placino
# Wilfredo Placino’s belief in turning every situation into an opportunity has brought him to where he is today: President and Vice Chairman of Clark Global City.
# By Ashton Kobler
# https://www.theceomagazine.com/executive-interviews/property-real-estate/wilfredo-placino/
# ----------------------------------------------------------------------
# EXECUTIVE-INTERVIEWS
# Grounded while flying high: Thierry Tea
# Chairman Thierry Tea keeps his feet firmly on the ground while his business Philjets Group is flying high.
# By Wendy Kay
# https://www.theceomagazine.com/executive-interviews/automotive-aviation/thierry-tea/
# ----------------------------------------------------------------------
# EXECUTIVE-INTERVIEWS
# Family matters: Low Su Ming
# ...

# %%
uid = driver.find_element_by_class_name("widget-body")
uid1 = driver.find_elements_by_class_name("widget-body")
title = driver.find_elements_by_class_name("post-title")
desc = driver.find_elements_by_class_name("post-excerpt")
author = driver.find_elements_by_class_name("post-meta")
for t,d,a,l in zip(title,desc,author,uid1):
#     link = l.find_elements_by_tag_name("a")
    print(t.text)
    print(d.text)
    print(a.text)
    lin = l.find_element_by_tag_name("a")
    print(lin.get_attribute("href"))
    print("-"*70)
# Out:
# Failures make us stronger: Wilfredo Placino
# Wilfredo Placino’s belief in turning every situation into an opportunity has brought him to where he is today: President and Vice Chairman of Clark Global City.
# By Ashton Kobler
# https://www.theceomagazine.com/executive-interviews
# ----------------------------------------------------------------------
# Grounded while flying high: Thierry Tea
# Chairman Thierry Tea keeps his feet firmly on the ground while his business Philjets Group is flying high.
# By Wendy Kay
# https://www.theceomagazine.com/executive-interviews
# ----------------------------------------------------------------------
# Family matters: Low Su Ming
# As Managing Director of the Low Yat Group’s property division and Group Executive Director, Low Su Ming is proud to continue her father’s legacy, yet she knows her family’s business must evolve with the times.
# By Jodie Darlington
# https://www.theceomagazine.com/executive-interviews
# ...

# %%
uid1 = driver.find_elements_by_class_name("widget-body")
# link = uid1.find_elements_by_tag_name("a")

for a in uid1:
    link = a.find_elements_by_tag_name("a")
    print(link[1].get_attribute("href"))
# Out:
# https://www.theceomagazine.com/executive-interviews/property-real-estate/wilfredo-placino/
# https://www.theceomagazine.com/executive-interviews/automotive-aviation/thierry-tea/
# https://www.theceomagazine.com/executive-interviews/property-real-estate/low-su-ming/
# https://www.theceomagazine.com/executive-interviews/services-consulting/seah-chee-kien-beh-swee-chiew/
# https://www.theceomagazine.com/executive-interviews/services-consulting/steven-du/
# https://www.theceomagazine.com/authors/writer/ashton-kobler/
# https://www.theceomagazine.com/authors/contributor/chrissie-mcclatchie/
# https://www.theceomagazine.com/authors/contributor/chrissie-mcclatchie/
# https://www.theceomagazine.com/authors/opinion/shane-cubis/
# https://www.theceomagazine.com/authors/opinion/shane-cubis/
# https://www.theceomagazine.com/authors/contributor/oliver-featherston/

# %%
uid = driver.find_elements_by_class_name("widget-body")

for a in uid:
    print(a.text)
    link = a.find_elements_by_tag_name("a")
#     for x in link:
    print(link[1].get_attribute("href"))
    print("-"*70)

# %%
driver1 = webdriver.Chrome('C:/Users/My PC/Downloads/chromedriver')
driver1.get("https://www.theceomagazine.com/business/start-ups-entrepreneurs/")

# %%
uid = driver1.find_elements_by_class_name("widget-body")

for a in uid:
    print(a.text)
    link = a.find_element_by_tag_name("a")
#     for x in link:
    print(link.get_attribute("href"))
    print("-"*70)
# Out:
# COVER STORYSTART-UPS & ENTREPRENEURS
# How Canva became one of the most successful start-up unicorns in history
# As Co-Founder and CEO of online design platform Canva, Melanie Perkins heads up one of Australia’s fastest-growing start-ups that now serves over 15 million users a month across 190 countries. But, says Melanie, this is just the beginning.
# By Ruth Devine
# https://www.theceomagazine.com/business/coverstory/
# ----------------------------------------------------------------------
# PHILANTHROPYSTART-UPS & ENTREPRENEURS
# Plastic trash to Blockchain treasure: Pollution could actually be saving the world
# How Plastic Bank is using blockchain to turn plastic waste into currency and tackle global poverty at the same time.
# By Emma Wheaton
# https://www.theceomagazine.com/business/philanthropy/
# ----------------------------------------------------------------------
# MARKETINGSTART-UPS & ENTREPRENEURS
# ...
